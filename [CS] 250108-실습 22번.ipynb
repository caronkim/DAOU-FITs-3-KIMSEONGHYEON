# %% [markdown]
# <a href="https://colab.research.google.com/github/caronkim/DAOU-FITs-3-KIMSEONGHYEON/blob/%EC%8B%A4%EC%8A%B5/%5BCS%5D%20250108-%EC%8B%A4%EC%8A%B5%2022%EB%B2%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a,b):
    return a + b

def subtract(a,b):
    return a - b

# %%
import unittest
from mymodule import add, subtract

class TestMathFunctions(unittest.TestCase):

    def test_add(self):
        # 1 + 2가 3이어야 한다는 테스트
        self.assertEqual(add(1, 2), 3)

    def test_subtract(self):
        # 5 - 3이 2이어야 한다는 테스트
        self.assertEqual(subtract(5, 3), 2)

    def test_add_negative(self):
        # -1 + -2가 -3이어야 한다는 테스트
        self.assertEqual(add(-1, -2), -3)

    def test_subtract_negative(self):
        # -5-(-3)이 -2이어야 한다는 테스트
        self.assertEqual(subtract(-5, -3), -2)

if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.017s
#
# OK
